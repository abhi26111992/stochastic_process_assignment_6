# %%
import numpy as np
import matplotlib.pyplot as plt

# Input Parameters
total_time = int(input("Enter time for simulation (Hours): "))
IAT_rate = int(input("Enter Job Arrival Rate (/Hour): "))
ST_rate = int(input("Enter Job Service Rate (/Hour): "))


# Initialize Parameters
IAT = []
ST = []
AT = []

n = int(np.random.poisson(IAT_rate)* total_time)

# Populate Inter-Arrival-Times (IAT)
for i in range(n):
    temp = np.random.exponential(1/IAT_rate)*60*60
    if i==0:
        IAT.append(0)
    else:
        IAT.append(int(temp))
        
# Populate Service-Times (ST) (where ST[i]!=0)
while not len(ST) == n:
    temp = np.random.exponential(1/ST_rate)*60*60
    if not int(temp)<1:
        ST.append(int(temp))

# Get Arrival-Times (AT) from IAT starting at t=0
# and initialize Waiting-Times to 0
for i in range(n):
    if i == 0:
        AT.append(0)    
    else:
        AT.append(AT[i-1] + IAT[i])
fig = plt.figure()
#fig.suptitle('Times between consecutive events in a simulated Poisson process')
plot, = plt.plot([i for i in range(n)], IAT, 'bo-', label='inter-arrival time')
plt.legend(handles=[plot])
plt.xlabel('Customer number')
plt.ylabel('Time')
plt.show()

plot, = plt.plot([i for i in range(n)], ST, 'bo-', label='service time')
plt.legend(handles=[plot])
plt.xlabel('Customer number')
plt.ylabel('Time')
plt.show()

rho2 = IAT_rate / ST_rate

pi = []
for j in range(n-1):
    p = (1-rho2)*(rho2**j)
    pi.append(p)
# Out:
# Enter time for simulation (Hours): 10
# Enter Job Arrival Rate (/Hour): 5
# Enter Job Service Rate (/Hour): 9

# %%
rho2 = IAT_rate / ST_rate
rho2
# Out:
# 0.5555555555555556

# %%
pi = []
for j in range(n-1):
    p = (1-rho2)*(rho2**j)
    pi.append(p)
pi
# Out:
# [0.4444444444444444,
#  0.24691358024691357,
#  0.13717421124828533,
#  0.0762078951379363,
#  0.04233771952107572,
#  0.023520955289486514,
#  0.013067197383048063,
#  0.0072595541016933695,
#  0.0040330856120518715,
#  0.0022406031178065955,
#  0.0012447795098925532,
#  0.0006915441721625296,
#  0.00038419120675696087,
#  0.00021343955930942272,
#  0.00011857753294967929,
#  6.587640719426628e-05,
#  3.6598003996814596e-05,
#  2.033222444267478e-05,
#  1.1295680245930434e-05,
#  6.275377914405797e-06,
#  3.486321063558776e-06,
#  1.936845035310431e-06,
#  1.0760250196169063e-06,
#  5.97791677564948e-07,
#  3.321064875360822e-07,
#  1.8450360418671236e-07,
#  1.0250200232595131e-07,
#  5.6945556847750725e-08,
#  3.1636420470972634e-08,
#  1.757578915054035e-08,
#  9.764327305855751e-09,
#  5.424626281030972e-09,
#  3.0136812672394294e-09,
#  1.674267370688572e-09,
#  9.30148539271429e-10,
#  5.167491884841272e-10,
#  2.8708288249118176e-10,
#  1.594904902728788e-10,
#  8.86058279293771e-11,
#  4.9225459960765057e-11,
#  2.7347477755980588e-11,
#  1.5193043197766994e-11,
#  8.440579554314998e-12,
#  4.6892108635083324e-12,
#  2.605117146393518e-12,
#  1.4472873035519544e-12,
#  8.04048501973308e-13,
#  4.466936122073934e-13,
#  2.4816311789299636e-13,
#  1.3786839882944243e-13,
#  7.659355490524579e-14,
#  4.255197494735878e-14,
#  2.3639986081865987e-14,
#  1.313332560103666e-14,
#  7.296292000575923e-15,
#  4.053495555875513e-15,
#  2.2519419754863964e-15,
#  1.2510788752702202e-15,
#  6.950438195945668e-16,
#  3.8613545533031487e-16,
#  2.1451969740573052e-16,
#  1.1917760966985028e-16,
#  6.620978314991683e-17,
#  3.6783212861064907e-17,
#  2.0435118256147173e-17,
#  1.1352843475637317e-17,
#  6.307135264242954e-18,
#  3.50396403569053e-18,
#  1.9466466864947392e-18,
#  1.0814703813859663e-18,
#  6.008168785477591e-19,
#  3.3378715474875506e-19,
#  1.854373081937528e-19,
#  1.0302072677430714e-19,
#  5.723373709683729e-20,
#  3.1796520609354056e-20,
#  1.7664733671863363e-20,
#  9.813740928812981e-21,
#  5.452078293784989e-21,
#  3.0289323854361053e-21,
#  1.6827402141311698e-21,
#  9.348556745173167e-22,
#  5.193642636207314e-22,
#  2.8853570201151745e-22,
#  1.6029761222862083e-22,
#  8.905422901590046e-23,
#  4.9474571675500264e-23,
#  2.74858731530557e-23,
#  1.526992952947539e-23,
#  8.483294183041883e-24,
#  4.712941212801047e-24,
#  2.6183006737783595e-24,
#  1.454611485432422e-24,
#  8.0811749190690115e-25,
#  4.4895416217050065e-25,
#  2.494189789836115e-25,
#  1.3856609943533972e-25,
#  7.698116635296651e-26,
#  4.2767314640536956e-26,
#  2.3759619244742754e-26,
#  1.319978846930153e-26,
#  7.333215816278628e-27,
#  4.07400878682146e-27,
#  2.263338214900811e-27,
#  1.2574101193893397e-27,
#  6.985611774385221e-28,
#  3.8808954302140118e-28,
#  2.1560530167855626e-28,
#  1.1978072315475346e-28,
#  6.654484619708526e-29,
#  3.69693589983807e-29,
#  2.0538532776878168e-29,
#  1.1410295987154539e-29,
#  6.339053326196966e-30,
#  3.521696292331648e-30,
#  1.956497940184249e-30,
#  1.0869433001023607e-30,
#  6.038573889457559e-31,
#  3.3547632719208663e-31,
#  1.8637573732893705e-31,
#  1.0354207629385392e-31,
#  5.752337571880773e-32,
#  3.1957430954893186e-32,
#  1.7754128308273994e-32]

# %%
np.transpose(pi)
# Out:
# array([4.44444444e-01, 2.46913580e-01, 1.37174211e-01, 7.62078951e-02,
#        4.23377195e-02, 2.35209553e-02, 1.30671974e-02, 7.25955410e-03,
#        4.03308561e-03, 2.24060312e-03, 1.24477951e-03, 6.91544172e-04,
#        3.84191207e-04, 2.13439559e-04, 1.18577533e-04, 6.58764072e-05,
#        3.65980040e-05, 2.03322244e-05, 1.12956802e-05, 6.27537791e-06,
#        3.48632106e-06, 1.93684504e-06, 1.07602502e-06, 5.97791678e-07,
#        3.32106488e-07, 1.84503604e-07, 1.02502002e-07, 5.69455568e-08,
#        3.16364205e-08, 1.75757892e-08, 9.76432731e-09, 5.42462628e-09,
#        3.01368127e-09, 1.67426737e-09, 9.30148539e-10, 5.16749188e-10,
#        2.87082882e-10, 1.59490490e-10, 8.86058279e-11, 4.92254600e-11,
#        2.73474778e-11, 1.51930432e-11, 8.44057955e-12, 4.68921086e-12,
#        2.60511715e-12, 1.44728730e-12, 8.04048502e-13, 4.46693612e-13,
#        2.48163118e-13, 1.37868399e-13, 7.65935549e-14, 4.25519749e-14,
#        2.36399861e-14, 1.31333256e-14, 7.29629200e-15, 4.05349556e-15,
#        2.25194198e-15, 1.25107888e-15, 6.95043820e-16, 3.86135455e-16,
#        2.14519697e-16, 1.19177610e-16, 6.62097831e-17, 3.67832129e-17,
#        2.04351183e-17, 1.13528435e-17, 6.30713526e-18, 3.50396404e-18,
#        1.94664669e-18, 1.08147038e-18, 6.00816879e-19, 3.33787155e-19,
#        1.85437308e-19, 1.03020727e-19, 5.72337371e-20, 3.17965206e-20,
#        1.76647337e-20, 9.81374093e-21, 5.45207829e-21, 3.02893239e-21,
#        1.68274021e-21, 9.34855675e-22, 5.19364264e-22, 2.88535702e-22,
#        1.60297612e-22, 8.90542290e-23, 4.94745717e-23, 2.74858732e-23,
#        1.52699295e-23, 8.48329418e-24, 4.71294121e-24, 2.61830067e-24,
#        1.45461149e-24, 8.08117492e-25, 4.48954162e-25, 2.49418979e-25,
#        1.38566099e-25, 7.69811664e-26, 4.27673146e-26, 2.37596192e-26,
#        1.31997885e-26, 7.33321582e-27, 4.07400879e-27, 2.26333821e-27,
#        1.25741012e-27, 6.98561177e-28, 3.88089543e-28, 2.15605302e-28,
#        1.19780723e-28, 6.65448462e-29, 3.69693590e-29, 2.05385328e-29,
#        1.14102960e-29, 6.33905333e-30, 3.52169629e-30, 1.95649794e-30,
#        1.08694330e-30, 6.03857389e-31, 3.35476327e-31, 1.86375737e-31,
#        1.03542076e-31, 5.75233757e-32, 3.19574310e-32, 1.77541283e-32])

# %%
Ls = rho2/(1-rho2)
Ls
# Out:
# 1.2500000000000002

# %%
Lq = Ls - rho2
Lq
# Out:
# 0.6944444444444446

# %%
Ws = Ls/IAT_rate
Ws
# Out:
# 0.25000000000000006

# %%
Wq = Ws - (1/ST_rate)
Wq
# Out:
# 0.13888888888888895
